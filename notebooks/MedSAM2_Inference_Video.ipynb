# %% [markdown]
# #   Video Segmentation with MedSAM2
# This notebook shows how to use MedSAM2 for video segmentation inference.
#
# If running locally using jupyter, first install `MedSAM2` in your environment using the [installation instructions](https://github.com/bowang-lab/MedSAM2?tab=readme-ov-file#installation) in the repository.

# %% [markdown]
# ## Load Packages and MedsSAM2 video predictor

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from sam2.build_sam import build_sam2_video_predictor

# helper functions
DAVIS_PALETTE = b"\x00\x00\x00\x80\x00\x00\x00\x80\x00\x80\x80\x00\x00\x00\x80\x80\x00\x80\x00\x80\x80\x80\x80\x80@\x00\x00\xc0\x00\x00@\x80\x00\xc0\x80\x00@\x00\x80\xc0\x00\x80@\x80\x80\xc0\x80\x80\x00@\x00\x80@\x00\x00\xc0\x00\x80\xc0\x00\x00@\x80\x80@\x80\x00\xc0\x80\x80\xc0\x80@@\x00\xc0@\x00@\xc0\x00\xc0\xc0\x00@@\x80\xc0@\x80@\xc0\x80\xc0\xc0\x80\x00\x00@\x80\x00@\x00\x80@\x80\x80@\x00\x00\xc0\x80\x00\xc0\x00\x80\xc0\x80\x80\xc0@\x00@\xc0\x00@@\x80@\xc0\x80@@\x00\xc0\xc0\x00\xc0@\x80\xc0\xc0\x80\xc0\x00@@\x80@@\x00\xc0@\x80\xc0@\x00@\xc0\x80@\xc0\x00\xc0\xc0\x80\xc0\xc0@@@\xc0@@@\xc0@\xc0\xc0@@@\xc0\xc0@\xc0@\xc0\xc0\xc0\xc0\xc0 \x00\x00\xa0\x00\x00 \x80\x00\xa0\x80\x00 \x00\x80\xa0\x00\x80 \x80\x80\xa0\x80\x80`\x00\x00\xe0\x00\x00`\x80\x00\xe0\x80\x00`\x00\x80\xe0\x00\x80`\x80\x80\xe0\x80\x80 @\x00\xa0@\x00 \xc0\x00\xa0\xc0\x00 @\x80\xa0@\x80 \xc0\x80\xa0\xc0\x80`@\x00\xe0@\x00`\xc0\x00\xe0\xc0\x00`@\x80\xe0@\x80`\xc0\x80\xe0\xc0\x80 \x00@\xa0\x00@ \x80@\xa0\x80@ \x00\xc0\xa0\x00\xc0 \x80\xc0\xa0\x80\xc0`\x00@\xe0\x00@`\x80@\xe0\x80@`\x00\xc0\xe0\x00\xc0`\x80\xc0\xe0\x80\xc0 @@\xa0@@ \xc0@\xa0\xc0@ @\xc0\xa0@\xc0 \xc0\xc0\xa0\xc0\xc0`@@\xe0@@`\xc0@\xe0\xc0@`@\xc0\xe0@\xc0`\xc0\xc0\xe0\xc0\xc0\x00 \x00\x80 \x00\x00\xa0\x00\x80\xa0\x00\x00 \x80\x80 \x80\x00\xa0\x80\x80\xa0\x80@ \x00\xc0 \x00@\xa0\x00\xc0\xa0\x00@ \x80\xc0 \x80@\xa0\x80\xc0\xa0\x80\x00`\x00\x80`\x00\x00\xe0\x00\x80\xe0\x00\x00`\x80\x80`\x80\x00\xe0\x80\x80\xe0\x80@`\x00\xc0`\x00@\xe0\x00\xc0\xe0\x00@`\x80\xc0`\x80@\xe0\x80\xc0\xe0\x80\x00 @\x80 @\x00\xa0@\x80\xa0@\x00 \xc0\x80 \xc0\x00\xa0\xc0\x80\xa0\xc0@ @\xc0 @@\xa0@\xc0\xa0@@ \xc0\xc0 \xc0@\xa0\xc0\xc0\xa0\xc0\x00`@\x80`@\x00\xe0@\x80\xe0@\x00`\xc0\x80`\xc0\x00\xe0\xc0\x80\xe0\xc0@`@\xc0`@@\xe0@\xc0\xe0@@`\xc0\xc0`\xc0@\xe0\xc0\xc0\xe0\xc0  \x00\xa0 \x00 \xa0\x00\xa0\xa0\x00  \x80\xa0 \x80 \xa0\x80\xa0\xa0\x80` \x00\xe0 \x00`\xa0\x00\xe0\xa0\x00` \x80\xe0 \x80`\xa0\x80\xe0\xa0\x80 `\x00\xa0`\x00 \xe0\x00\xa0\xe0\x00 `\x80\xa0`\x80 \xe0\x80\xa0\xe0\x80``\x00\xe0`\x00`\xe0\x00\xe0\xe0\x00``\x80\xe0`\x80`\xe0\x80\xe0\xe0\x80  @\xa0 @ \xa0@\xa0\xa0@  \xc0\xa0 \xc0 \xa0\xc0\xa0\xa0\xc0` @\xe0 @`\xa0@\xe0\xa0@` \xc0\xe0 \xc0`\xa0\xc0\xe0\xa0\xc0 `@\xa0`@ \xe0@\xa0\xe0@ `\xc0\xa0`\xc0 \xe0\xc0\xa0\xe0\xc0``@\xe0`@`\xe0@\xe0\xe0@``\xc0\xe0`\xc0`\xe0\xc0\xe0\xe0\xc0"

def load_ann_png(path):
    """Load a PNG file as a mask and its palette."""
    mask = Image.open(path)
    palette = mask.getpalette()
    mask = np.array(mask).astype(np.uint8)
    return mask, palette

def get_per_obj_mask(mask):
    """Split a mask into per-object masks."""
    object_ids = np.unique(mask)
    object_ids = object_ids[object_ids > 0].tolist()
    per_obj_mask = {object_id: (mask == object_id) for object_id in object_ids}
    return per_obj_mask

def put_per_obj_mask(per_obj_mask, height, width):
    """Combine per-object masks into a single mask."""
    mask = np.zeros((height, width), dtype=np.uint8)
    object_ids = sorted(per_obj_mask)[::-1]
    for object_id in object_ids:
        object_mask = per_obj_mask[object_id]
        object_mask = object_mask.reshape(height, width)
        mask[object_mask] = object_id
    return mask

def load_masks_from_dir(input_mask_path):
    input_mask, input_palette = load_ann_png(input_mask_path)
    per_obj_input_mask = get_per_obj_mask(input_mask)

    return per_obj_input_mask, input_palette

def save_predictions_to_dir(
    output_mask_dir,
    video_name,
    frame_name,
    per_obj_output_mask,
    height,
    width,
):
    """Save masks to a directory as PNG files."""
    os.makedirs(os.path.join(output_mask_dir, video_name), exist_ok=True)

    output_mask = put_per_obj_mask(per_obj_output_mask, height, width)
    output_mask_path = os.path.join(
        output_mask_dir, video_name, f"{frame_name}.png"
    )
    assert output_mask.dtype == np.uint8
    assert output_mask.ndim == 2
    output_mask = Image.fromarray(output_mask)
    output_mask.save(output_mask_path)

def create_overlay(img_path, mask_path, palette):
    """Create an overlay of an image and a mask."""
    img = Image.open(img_path)
    mask = Image.open(mask_path)
    mask.putpalette(palette)
    mask_rgb = mask.convert("RGB")
    mask_rgb = mask_rgb.resize(img.size, Image.NEAREST)
    overlay = Image.blend(img, mask_rgb, alpha=0.5)
    return overlay

# %%
# change to customized path
VIDEO_DIR = "/mnt/bb586fde-943d-4653-af27-224147bfba7e/Medgemma/sam/sam3/test/png"
# VIDEO_NAME = "patient0213_4CH"
# INITIAL_MASK_PROMPT = "/media/jma/MyPassport/MedSAM2/datasets/Demo/masks/patient0213_4CH/patient0213_4CH_half_sequence-000.png"
# OUTPUT_DIR = "/media/jma/MyPassport/MedSAM2/datasets/Demo/output"
VIDEO_NAME = "BraTS-GLI-00005-100/jpeg"
INITIAL_MASK_PROMPT = VIDEO_DIR + "/" + VIDEO_NAME.split("/")[0] + "/" + f"{VIDEO_NAME.split('/')[0]}-seg_slice_133.png"
OUTPUT_DIR = "/mnt/bb586fde-943d-4653-af27-224147bfba7e/Medgemma/MedSAM2/output"

MODEL_CONFIG = "configs/sam2.1_hiera_t512.yaml"
MODEL_CHECKPOINT = "../checkpoints/MedSAM2_latest.pt"

predictor = build_sam2_video_predictor(
    config_file=MODEL_CONFIG,
    ckpt_path=MODEL_CHECKPOINT,
    apply_postprocessing=True,
    # hydra_overrides_extra=hydra_overrides_extra,
    vos_optimized=  True,
)

# %% [markdown]
# ## Prepare Inference and Add Initial Mask Prompt

# %%
# load the video frames
frame_names = [
        os.path.splitext(p)[0]
        for p in os.listdir(os.path.join(VIDEO_DIR, VIDEO_NAME))
        if os.path.splitext(p)[-1] in [".jpg", ".jpeg", ".JPG", ".JPEG"]
    ]
frame_names = list(sorted(frame_names))
inference_state = predictor.init_state(
    video_path=os.path.join(VIDEO_DIR, VIDEO_NAME), async_loading_frames=False
)
height = inference_state["video_height"]
width = inference_state["video_width"]
input_palette = None

# Add input masks to MedSAM2 inference state before propagation
object_ids_set = None
input_frame_idx = 0  # use first frame as mask input
try:
    per_obj_input_mask, input_palette = load_masks_from_dir(input_mask_path=INITIAL_MASK_PROMPT)
except FileNotFoundError as e:
    raise RuntimeError(
        f"In {VIDEO_NAME=}, failed to load input mask for frame {input_frame_idx=}. "
        "Please add the `--track_object_appearing_later_in_video` flag "
        "for VOS datasets that don't have all objects to track appearing "
        "in the first frame (such as LVOS or YouTube-VOS)."
    ) from e

# get the list of object ids to track from the first input frame
if object_ids_set is None:
    object_ids_set = set(per_obj_input_mask)
for object_id, object_mask in per_obj_input_mask.items():
    # check and make sure no new object ids appear only in later frames
    if object_id not in object_ids_set:
        raise RuntimeError(
            f"In {VIDEO_NAME=}, got a new {object_id=} appearing only in a "
            f"later {input_frame_idx=} (but not appearing in the first frame). "
            "Please add the `--track_object_appearing_later_in_video` flag "
            "for VOS datasets that don't have all objects to track appearing "
            "in the first frame (such as LVOS or YouTube-VOS)."
        )
    predictor.add_new_mask(
        inference_state=inference_state,
        frame_idx=input_frame_idx,
        obj_id=object_id,
        mask=object_mask,
            )
    
# check and make sure we have at least one object to track
if object_ids_set is None or len(object_ids_set) == 0:
    raise RuntimeError(
        f"In {VIDEO_NAME=}, got no object ids on {input_frame_idx=}. "
        "Please add the `--track_object_appearing_later_in_video` flag "
        "for VOS datasets that don't have all objects to track appearing "
        "in the first frame (such as LVOS or YouTube-VOS)."
    )
# Out:
# frame loading (JPEG):   0%|          | 0/131 [00:00<?, ?it/s]
# frame loading (JPEG): 100%|██████████| 131/131 [00:00<00:00, 329.39it/s]
# /mnt/bb586fde-943d-4653-af27-224147bfba7e/Medgemma/MedSAM2/sam2/modeling/sam/transformer.py:270: UserWarning: Memory efficient kernel not used because: (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:773.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /mnt/bb586fde-943d-4653-af27-224147bfba7e/Medgemma/MedSAM2/sam2/modeling/sam/transformer.py:270: UserWarning: Memory Efficient attention has been runtime disabled. (Triggered internally at ../aten/src/ATen/native/transformers/sdp_utils_cpp.h:558.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /mnt/bb586fde-943d-4653-af27-224147bfba7e/Medgemma/MedSAM2/sam2/modeling/sam/transformer.py:270: UserWarning: Flash attention kernel not used because: (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:775.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /mnt/bb586fde-943d-4653-af27-224147bfba7e/Medgemma/MedSAM2/sam2/modeling/sam/transformer.py:270: UserWarning: Expected query, key and value to all be of dtype: {Half, BFloat16}. Got Query dtype: float, Key dtype: float, and Value dtype: float instead. (Triggered internally at ../aten/src/ATen/native/transformers/sdp_utils_cpp.h:100.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /mnt/bb586fde-943d-4653-af27-224147bfba7e/Medgemma/MedSAM2/sam2/modeling/sam/transformer.py:270: UserWarning: CuDNN attention kernel not used because: (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:777.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/biomedialab/miniconda3/envs/medsam2/lib/python3.12/site-packages/torch/nn/modules/module.py:1747: UserWarning: Flash Attention kernel failed due to: No available kernel. Aborting execution.
# Falling back to all available kernels for scaled_dot_product_attention (which may have a slower speed).
#   return forward_call(*args, **kwargs)
# /mnt/bb586fde-943d-4653-af27-224147bfba7e/Medgemma/MedSAM2/sam2/sam2_video_predictor.py:961: UserWarning: /mnt/bb586fde-943d-4653-af27-224147bfba7e/Medgemma/MedSAM2/sam2/_C.so: undefined symbol: _ZN3c106detail23torchInternalAssertFailEPKcS2_jS2_RKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
#   pred_masks_gpu = fill_holes_in_mask_scores(

# %% [markdown]
# ## Run Inference

# %%
# run propagation throughout the video
os.makedirs(os.path.join(OUTPUT_DIR, VIDEO_NAME), exist_ok=True)

video_segments = {}  # Store the per-frame segmentation results
for out_frame_idx, out_obj_ids, out_mask_logits in predictor.propagate_in_video(
    inference_state
):
    per_obj_output_mask = {
        out_obj_id: (out_mask_logits[i] > 0.0).cpu().numpy()
        for i, out_obj_id in enumerate(out_obj_ids)
    }
    video_segments[out_frame_idx] = per_obj_output_mask

# write the output masks
for out_frame_idx, per_obj_output_mask in video_segments.items():
    # save raw prediction results
    save_predictions_to_dir(
        output_mask_dir=OUTPUT_DIR,
        video_name=VIDEO_NAME,
        frame_name=frame_names[out_frame_idx],
        per_obj_output_mask=per_obj_output_mask,
        height=height,
        width=width,
    )
# Out:
# propagate in video: 100%|██████████| 131/131 [00:10<00:00, 12.70it/s]

# %% [markdown]
# ## Visualize Inference Results
# Visualize segmentation results for 3 key frames at the 25%, 50%, and 75% position in the sequence

# %%
output_palette = input_palette or DAVIS_PALETTE
images = sorted(os.listdir(os.path.join(VIDEO_DIR, VIDEO_NAME)))
print("Images:", images)
masks = sorted(os.listdir(os.path.join(OUTPUT_DIR, VIDEO_NAME)))
# print("Masks:", len(masks))
num_frames = len(images)
# print("Total number of frames:", num_frames)
selected_indices = [int(num_frames * 0.25), int(num_frames * 0.5), int(num_frames * 0.75)]
print("Selected frame indices for visualization:", selected_indices)
selected_frames = [(images[i], masks[i]) for i in selected_indices]

plt.figure(figsize=(12, 4))
for idx, (img, mask) in enumerate(selected_frames):
    overlay = create_overlay(os.path.join(VIDEO_DIR, VIDEO_NAME, img), os.path.join(OUTPUT_DIR, VIDEO_NAME, mask), output_palette)

    plt.subplot(1, 3, idx + 1)
    plt.imshow(overlay)
    plt.title(f"Frame {int(num_frames*0.25*(idx+1))}")
    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Images: ['BraTS-GLI-00005-100-t2f_slice_100.jpeg', 'BraTS-GLI-00005-100-t2f_slice_101.jpeg', 'BraTS-GLI-00005-100-t2f_slice_102.jpeg', 'BraTS-GLI-00005-100-t2f_slice_103.jpeg', 'BraTS-GLI-00005-100-t2f_slice_104.jpeg', 'BraTS-GLI-00005-100-t2f_slice_105.jpeg', 'BraTS-GLI-00005-100-t2f_slice_106.jpeg', 'BraTS-GLI-00005-100-t2f_slice_107.jpeg', 'BraTS-GLI-00005-100-t2f_slice_108.jpeg', 'BraTS-GLI-00005-100-t2f_slice_109.jpeg', 'BraTS-GLI-00005-100-t2f_slice_110.jpeg', 'BraTS-GLI-00005-100-t2f_slice_111.jpeg', 'BraTS-GLI-00005-100-t2f_slice_112.jpeg', 'BraTS-GLI-00005-100-t2f_slice_113.jpeg', 'BraTS-GLI-00005-100-t2f_slice_114.jpeg', 'BraTS-GLI-00005-100-t2f_slice_115.jpeg', 'BraTS-GLI-00005-100-t2f_slice_116.jpeg', 'BraTS-GLI-00005-100-t2f_slice_117.jpeg', 'BraTS-GLI-00005-100-t2f_slice_118.jpeg', 'BraTS-GLI-00005-100-t2f_slice_119.jpeg', 'BraTS-GLI-00005-100-t2f_slice_120.jpeg', 'BraTS-GLI-00005-100-t2f_slice_121.jpeg', 'BraTS-GLI-00005-100-t2f_slice_122.jpeg', 'BraTS-GLI-00005-100-t2f_slice_123.jpeg', 'BraTS-GLI-00005-100-t2f_slice_124.jpeg', 'BraTS-GLI-00005-100-t2f_slice_125.jpeg', 'BraTS-GLI-00005-100-t2f_slice_126.jpeg', 'BraTS-GLI-00005-100-t2f_slice_127.jpeg', 'BraTS-GLI-00005-100-t2f_slice_128.jpeg', 'BraTS-GLI-00005-100-t2f_slice_129.jpeg', 'BraTS-GLI-00005-100-t2f_slice_130.jpeg', 'BraTS-GLI-00005-100-t2f_slice_131.jpeg', 'BraTS-GLI-00005-100-t2f_slice_132.jpeg', 'BraTS-GLI-00005-100-t2f_slice_133.jpeg', 'BraTS-GLI-00005-100-t2f_slice_134.jpeg', 'BraTS-GLI-00005-100-t2f_slice_135.jpeg', 'BraTS-GLI-00005-100-t2f_slice_136.jpeg', 'BraTS-GLI-00005-100-t2f_slice_137.jpeg', 'BraTS-GLI-00005-100-t2f_slice_138.jpeg', 'BraTS-GLI-00005-100-t2f_slice_139.jpeg', 'BraTS-GLI-00005-100-t2f_slice_140.jpeg', 'BraTS-GLI-00005-100-t2f_slice_141.jpeg', 'BraTS-GLI-00005-100-t2f_slice_142.jpeg', 'BraTS-GLI-00005-100-t2f_slice_143.jpeg', 'BraTS-GLI-00005-100-t2f_slice_144.jpeg', 'BraTS-GLI-00005-100-t2f_slice_145.jpeg', 'BraTS-GLI-00005-100-t2f_slice_146.jpeg', 'BraTS-GLI-00005-100-t2f_slice_147.jpeg', 'BraTS-GLI-00005-100-t2f_slice_148.jpeg', 'BraTS-GLI-00005-100-t2f_slice_149.jpeg', 'BraTS-GLI-00005-100-t2f_slice_150.jpeg', 'BraTS-GLI-00005-100-t2f_slice_151.jpeg', 'BraTS-GLI-00005-100-t2f_slice_152.jpeg', 'BraTS-GLI-00005-100-t2f_slice_153.jpeg', 'BraTS-GLI-00005-100-t2f_slice_154.jpeg', 'BraTS-GLI-00005-100-t2f_slice_155.jpeg', 'BraTS-GLI-00005-100-t2f_slice_156.jpeg', 'BraTS-GLI-00005-100-t2f_slice_157.jpeg', 'BraTS-GLI-00005-100-t2f_slice_158.jpeg', 'BraTS-GLI-00005-100-t2f_slice_159.jpeg', 'BraTS-GLI-00005-100-t2f_slice_160.jpeg', 'BraTS-GLI-00005-100-t2f_slice_161.jpeg', 'BraTS-GLI-00005-100-t2f_slice_31.jpeg', 'BraTS-GLI-00005-100-t2f_slice_32.jpeg', 'BraTS-GLI-00005-100-t2f_slice_33.jpeg', 'BraTS-GLI-00005-100-t2f_slice_34.jpeg', 'BraTS-GLI-00005-100-t2f_slice_35.jpeg', 'BraTS-GLI-00005-100-t2f_slice_36.jpeg', 'BraTS-GLI-00005-100-t2f_slice_37.jpeg', 'BraTS-GLI-00005-100-t2f_slice_38.jpeg', 'BraTS-GLI-00005-100-t2f_slice_39.jpeg', 'BraTS-GLI-00005-100-t2f_slice_40.jpeg', 'BraTS-GLI-00005-100-t2f_slice_41.jpeg', 'BraTS-GLI-00005-100-t2f_slice_42.jpeg', 'BraTS-GLI-00005-100-t2f_slice_43.jpeg', 'BraTS-GLI-00005-100-t2f_slice_44.jpeg', 'BraTS-GLI-00005-100-t2f_slice_45.jpeg', 'BraTS-GLI-00005-100-t2f_slice_46.jpeg', 'BraTS-GLI-00005-100-t2f_slice_47.jpeg', 'BraTS-GLI-00005-100-t2f_slice_48.jpeg', 'BraTS-GLI-00005-100-t2f_slice_49.jpeg', 'BraTS-GLI-00005-100-t2f_slice_50.jpeg', 'BraTS-GLI-00005-100-t2f_slice_51.jpeg', 'BraTS-GLI-00005-100-t2f_slice_52.jpeg', 'BraTS-GLI-00005-100-t2f_slice_53.jpeg', 'BraTS-GLI-00005-100-t2f_slice_54.jpeg', 'BraTS-GLI-00005-100-t2f_slice_55.jpeg', 'BraTS-GLI-00005-100-t2f_slice_56.jpeg', 'BraTS-GLI-00005-100-t2f_slice_57.jpeg', 'BraTS-GLI-00005-100-t2f_slice_58.jpeg', 'BraTS-GLI-00005-100-t2f_slice_59.jpeg', 'BraTS-GLI-00005-100-t2f_slice_60.jpeg', 'BraTS-GLI-00005-100-t2f_slice_61.jpeg', 'BraTS-GLI-00005-100-t2f_slice_62.jpeg', 'BraTS-GLI-00005-100-t2f_slice_63.jpeg', 'BraTS-GLI-00005-100-t2f_slice_64. ...
# Selected frame indices for visualization: [32, 65, 98]
